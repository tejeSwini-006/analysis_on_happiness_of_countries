# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
world_Happines=pd.read_csv('rankings.csv')
world_Happines
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 141   142     Botswana            3.471         3.667        3.275
# 142   143       Rwanda            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                         2.518                         1.892
# ...

# %%
world_Happines.describe().T
# Out:
#                                             count       mean        std  \
# RANK                                        146.0  73.500000  42.290661
# Happiness score                             146.0   5.553575   1.086843
# Whisker-high                                146.0   5.673589   1.065621
# Whisker-low                                 146.0   5.433568   1.109380
# Dystopia (1.83) + residual                  146.0   1.831808   0.534994
# Explained by: GDP per capita                146.0   1.410445   0.421663
# Explained by: Social support                146.0   0.905863   0.280122
# Explained by: Healthy life expectancy       146.0   0.586171   0.176336
# Explained by: Freedom to make life choices  146.0   0.517226   0.145859
# Explained by: Generosity                    146.0   0.147377   0.082799
# Explained by: Perceptions of corruption     146.0   0.154781   0.127514
#
#                                               min       25%      50%  \
# ...

# %%
world_Happines.isnull().sum()
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               0
# Whisker-high                                  0
# Whisker-low                                   0
# Dystopia (1.83) + residual                    0
# Explained by: GDP per capita                  0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# dtype: int64

# %%
fig,ax=plt.subplots(figsize=(20,10))
ax=sns.heatmap(world_Happines.corr(),annot=True,linewidths=0.5,fmt='.2f',cmap='YlGnBu');

# %%
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number])
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]]
    columnNames = list(df)
    if len(columnNames) > 10:
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
plotScatterMatrix(world_Happines, 20, 10)
# Out:
# C:\Users\Hello\AppData\Local\Temp/ipykernel_29232/3879777494.py:3: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.dropna will be keyword-only

# %%
import plotly.express as px
fig = px.choropleth(world_Happines, locations = "Country",locationmode = 'country names', color = "Happiness score",
                    scope = 'world', title = "Happiness Ranking World Map", color_continuous_scale= "viridis")

# %%
fig
